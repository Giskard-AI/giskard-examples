# %% [markdown]
# # Fake/real news classification [tensorflow (keras)]
# Binary classification of news being fake or real, based on their text.
# Reference notebook: <Reference notebook: <https://www.kaggle.com/code/madz2000/nlp-using-glove-embeddings-99-87-accuracy/notebook>
# Dataset: <https://www.kaggle.com/code/madz2000/nlp-using-glove-embeddings-99-87-accuracy/input>

# %% [markdown]
# ## Import libraries

# %%
import os
import re, string

import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from keras.optimizers import Adam
from keras.models import Sequential
from keras.utils import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.layers import Dense, Embedding, LSTM
from sklearn.model_selection import train_test_split

import giskard
from giskard import Dataset, Model
# Out:
# 2023-05-15 18:13:48.588040: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Define constants

# %%
# Constants.
MAX_TOKENS = 10000
MAX_SEQUENCE_LENGTH = 300

STOPWORDS = stopwords.words('english')

# Paths.
DATA_DIRECTORY = os.path.join(".", "datasets", "fake_real_news_dataset")
EMBEDDING_FILE = os.path.join(DATA_DIRECTORY, "glove_100d.txt")

# %% [markdown]
# ## Load data

# %%
def load_data(**kwargs):
    # Load and label real news data.
    real_df = pd.read_csv(os.path.join(DATA_DIRECTORY, "True.csv"), **kwargs)
    real_df['category'] = 1

    # Load and label fake news data.
    fake_df = pd.read_csv(os.path.join(DATA_DIRECTORY, "Fake.csv"), **kwargs)
    fake_df['category'] = 0

    # Create common df.
    full_df = pd.concat([real_df, fake_df])

    # Drop useless columns.
    full_df.drop(columns=["subject", "date"], inplace=True)

    return full_df

# %%
news_df = load_data(nrows=2000)
news_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text  category
# 0  WASHINGTON (Reuters) - The head of a conservat...         1
# 1  WASHINGTON (Reuters) - Transgender people will...         1
# 2  WASHINGTON (Reuters) - The special counsel inv...         1
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...         1
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...         1

# %% [markdown]
# ## Train-test split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(news_df[["title", "text"]], news_df.category, random_state=0)

# %% [markdown]
# ## Define text preprocessing logic

# %%
def clean_text(df: pd.DataFrame) -> np.ndarray:
    # Merge text data into single column.
    df.text = df.text + " " + df.title
    df.drop(columns=["title"], inplace=True)

    # Remove text inside square brackets.
    df.text = df.text.apply(lambda sentence: re.sub('\[[^]]*\]', '', sentence))

    # Remove punctuation.
    df.text = df.text.apply(lambda text: text.translate(str.maketrans('', '', string.punctuation)))

    # Remove stop words.
    df.text = df.text.apply(lambda sentence: ' '.join([_word for _word in sentence.split() if _word.lower() not in STOPWORDS]))

    return df.text

# %% [markdown]
# ## Wrap data with giskard

# %%
raw_data = pd.concat([X_test.copy(), Y_test.copy()], axis=1)
wrapped_data = Dataset(raw_data, name="fake_and_real_news", target="category", column_types={"title": "text", "text": "text"})
# Out:
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.

# %%
X_train = clean_text(X_train)
X_test = clean_text(X_test)

# %%
# Fit tokenizer.
tokenizer = Tokenizer(num_words=MAX_TOKENS)
tokenizer.fit_on_texts(X_train)

# Tokenize train text.
tokenized_train = tokenizer.texts_to_sequences(X_train)
X_train = pad_sequences(tokenized_train, maxlen=MAX_SEQUENCE_LENGTH)

# Tokenize test text.
tokenized_test = tokenizer.texts_to_sequences(X_test)
X_test = pad_sequences(tokenized_test, maxlen=MAX_SEQUENCE_LENGTH)

# %% [markdown]
# ## Define preprocessing function

# %%
def preprocessing_function(df: pd.DataFrame) -> np.ndarray:
    cleaned_text = clean_text(df)
    tokens = tokenizer.texts_to_sequences(cleaned_text)
    tokens_with_padding = pad_sequences(tokens, maxlen=MAX_SEQUENCE_LENGTH)

    return tokens_with_padding

# %% [markdown]
# ## Create embeddings matrix

# %%
def parse_line(word, *arr):
    return word, np.asarray(arr, dtype='float32')

def init_embeddings_matrix(embeddings_dict):
    num_embeddings = min(MAX_TOKENS, len(tokenizer.word_index))

    stacked_embeddings = np.stack(embeddings_dict.values())
    embeddings_mean, embeddings_std, embeddings_dimension = stacked_embeddings.mean(), stacked_embeddings.std(), stacked_embeddings.shape[1]

    embeddings_matrix = np.random.normal(embeddings_mean, embeddings_std, (num_embeddings, embeddings_dimension))

    return embeddings_matrix

def get_embeddings_matrix():
    embeddings_dict = dict(parse_line(*line.rstrip().rsplit(' ')) for line in open(EMBEDDING_FILE))
    embeddings_matrix = init_embeddings_matrix(embeddings_dict)

    for word, idx in tokenizer.word_index.items():
        if idx >= MAX_TOKENS:
            continue

        embedding_vector = embeddings_dict.get(word, None)

        if embedding_vector is not None:
            embeddings_matrix[idx] = embedding_vector

    return embeddings_matrix

embed_matrix = get_embeddings_matrix()
# Out:
# /var/folders/4q/3_bfyqnn7yv5jcjq98x2jf680000gn/T/ipykernel_8347/2290666688.py:29: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   embed_matrix = get_embeddings_matrix()

# %% [markdown]
# ## Train model

# %%
# Define model container.
model = Sequential()

# Non-trainable embedding layer.
model.add(Embedding(MAX_TOKENS, output_dim=100, weights=[embed_matrix], input_length=MAX_SEQUENCE_LENGTH, trainable=False))

# LSTM stage.
model.add(LSTM(units=32 , return_sequences=True , recurrent_dropout=0.25, dropout=0.25))
model.add(LSTM(units=16 , recurrent_dropout=0.1 , dropout=0.1))

# Dense stage.
model.add(Dense(units=16 , activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# Build model.
model.compile(optimizer=Adam(lr=0.01), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 100)          1000000
#
#  lstm (LSTM)                 (None, 300, 32)           17024
#
#  lstm_1 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,020,449
# Trainable params: 20,449
# Non-trainable params: 1,000,000
# _________________________________________________________________
# /Users/mykytaalekseiev/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Define hyperparameters.
n_epochs = 1
batch_size = 256

# Fit model.
_ = model.fit(X_train, Y_train, batch_size=batch_size, validation_data=(X_test, Y_test), epochs=n_epochs)
# Out:
# 12/12 [==============================] - 18s 971ms/step - loss: 0.4055 - accuracy: 0.8223 - val_loss: 0.0952 - val_accuracy: 0.9740

# %% [markdown]
# ## Calculate train and test accuracy

# %%
train_accuracy = model.evaluate(X_train, Y_train)[1]
test_accuracy = model.evaluate(X_test, Y_test)[1]
# Out:
# 94/94 [==============================] - 4s 44ms/step - loss: 0.1035 - accuracy: 0.9700
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0952 - accuracy: 0.9740

# %%
print(f"Train accuracy: {train_accuracy: .2f}")
print(f"Test accuracy: {test_accuracy: .2f}")
# Out:
# Train accuracy:  0.97
# Test accuracy:  0.97

# %% [markdown]
# ## Wrap data and model and run scanner

# %%
wrapped_model = Model(model,
                      model_type="classification",
                      data_preprocessing_function=preprocessing_function,
                      name="fake_real_news_classification",
                      feature_names=["title", "text"],
                      classification_threshold=0.5,
                      classification_labels=[1, 0]
                      )
# Out:
# Your 'model' is successfully wrapped by Giskard's 'TensorFlowModel' wrapper class.

# %%
wrapped_pred = wrapped_model.predict(wrapped_data)
# Out:
# 32/32 [==============================] - 2s 56ms/step
# 2023-05-15 18:23:58,001 pid:8347 MainThread giskard.models.base WARNING
# Your binary classification model prediction is of the shape (1000, 1).
# In Giskard we expect the shape (1000, 2) for binary classification models.
# We automatically inferred the second class prediction but please make sure that
# the probability output of your model corresponds to the first label of the
# classification_labels ([1, 0]) you provided us with.
# NoneType: None

# %%
scanning_results = giskard.scan(wrapped_model, wrapped_data)
# Out:
# 2023/05/15 18:15:05 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# 2023-05-15 18:15:06.743152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'while/Placeholder_2' with dtype float and shape [?,32]
# 	 [[{{node while/Placeholder_2}}]]
# 2023-05-15 18:15:06.974192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'while/Placeholder_2' with dtype float and shape [?,32]
# 	 [[{{node while/Placeholder_2}}]]
# 2023-05-15 18:15:07.046122: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:07.064011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:07.082040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:07.082153: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'states' with dtype float and shape [?,32]
# 	 [[{{node states}}]]
# 2023-05-15 18:15:07.097480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:07.097556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'states' with dtype float and shape [?,32]
# 	 [[{{node states}}]]
# 2023-05-15 18:15:07.346809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'while/Placeholder_2' with dtype float and shape [?,16]
# 	 [[{{node while/Placeholder_2}}]]
# 2023-05-15 18:15:07.516765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'while/Placeholder_2' with dtype float and shape [?,16]
# 	 [[{{node while/Placeholder_2}}]]
# 2023-05-15 18:15:07.587846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:07.609519: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:07.626101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:07.626209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'states' with dtype float and shape [?,16]
# 	 [[{{node states}}]]
# 2023-05-15 18:15:07.643133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:07.643277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'states' with dtype float and shape [?,16]
# 	 [[{{node states}}]]
# 2023-05-15 18:15:09.208252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,300,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:09.225378: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,300,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:09.247886: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,300,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:09.259853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,300,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:10.887703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_0' with dtype float and shape [?,?,100]
# 	 [[{{node inputs_0}}]]
# 2023-05-15 18:15:10.900000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_0' with dtype float and shape [?,?,100]
# 	 [[{{node inputs_0}}]]
# 2023-05-15 18:15:10.911828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,300,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:10.922371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,300,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:11.851697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_0' with dtype float and shape [?,?,32]
# 	 [[{{node inputs_0}}]]
# 2023-05-15 18:15:11.863623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_0' with dtype float and shape [?,?,32]
# 	 [[{{node inputs_0}}]]
# 2023-05-15 18:15:11.874705: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,300,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:11.886188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,300,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:12.846745: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:12.846821: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'states_0' with dtype float and shape [?,32]
# 	 [[{{node states_0}}]]
# 2023-05-15 18:15:12.858539: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,100]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:12.858639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'states_0' with dtype float and shape [?,32]
# 	 [[{{node states_0}}]]
# 2023-05-15 18:15:13.037771: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:13.037846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'states_0' with dtype float and shape [?,16]
# 	 [[{{node states_0}}]]
# 2023-05-15 18:15:13.050376: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-15 18:15:13.050531: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'states_0' with dtype float and shape [?,16]
# 	 [[{{node states_0}}]]
# INFO:tensorflow:Assets written to: /var/folders/4q/3_bfyqnn7yv5jcjq98x2jf680000gn/T/giskard-model-4e98i2mb/data/model/assets
# 2023-05-15 18:15:16,534 pid:8347 MainThread tensorflow   INFO     Assets written to: /var/folders/4q/3_bfyqnn7yv5jcjq98x2jf680000gn/T/giskard-model-4e98i2mb/data/model/assets
# /Users/mykytaalekseiev/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Hint: "Your target variable values are numeric. It is recommended to have Human readable string as your target values to make results more understandable in Giskard."
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 1/1 [==============================] - 1s 564ms/step
# 2023-05-15 18:15:53,805 pid:8347 MainThread giskard.models.base WARNING
# Your binary classification model prediction is of the shape (10, 1).
# In Giskard we expect the shape (10, 2) for binary classification models.
# We automatically inferred the second class prediction but please make sure that
# the probability output of your model corresponds to the first label of the
# classification_labels ([1, 0]) you provided us with.
# NoneType: None
# 1/1 [==============================] - 0s 61ms/step
# 2023-05-15 18:15:53,932 pid:8347 MainThread giskard.models.base WARNING
# Your binary classification model prediction is of the shape (10, 1).
# In Giskard we expect the shape (10, 2) for binary classification models.
# We automatically inferred the second class prediction but please make sure that
# the probability output of your model corresponds to the first label of the
# classification_labels ([1, 0]) you provided us with.
# NoneType: None
# Your model is successfully validated.
# Running scan…
# 32/32 [==============================] - 1s 46ms/step
# 2023-05-15 18:15:57,203 pid:8347 MainThread giskard.models.base WARNING
# Your binary classification model prediction is of the shape (1000, 1).
# In Giskard we expect the shape (1000, 2) for binary classification models.
# We automatically inferred the second class prediction but please make sure that
# the probability output of your model corresponds to the first label of the
# classification_labels ([1, 0]) you provided us with.
# NoneType: None
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# ...
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 32/32 [==============================] - 2s 53ms/step
# 2023-05-15 18:17:10,914 pid:8347 MainThread giskard.models.base WARNING
# Your binary classification model prediction is of the shape (1000, 1).
# In Giskard we expect the shape (1000, 2) for binary classification models.
# We automatically inferred the second class prediction but please make sure that
# the probability output of your model corresponds to the first label of the
# classification_labels ([1, 0]) you provided us with.
# NoneType: None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 scanning_results = giskard.scan(wrapped_model, wrapped_data)
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/giskard/scanner/__init__.py:35, in scan(model, dataset, params, only, verbose)
#      23 """
#      24 Scan a model with a dataset.
#      25
#    (...)
#      32         Scanner configuration.
#      33 """
#      34 scanner = Scanner(params, only=only)
# ---> 35 return scanner.analyze(model, dataset, verbose=verbose)
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/giskard/scanner/scanner.py:44, in Scanner.analyze(self, model, dataset, verbose)
#      42 for detector in detectors:
#      43     maybe_print(f"Running detector {detector.__class__.__name__}…", end="", verbose=verbose)
# ---> 44     detected_issues = detector.run(model, dataset)
#      45     detected_issues = sorted(detected_issues, key=lambda i: -i.importance)[:MAX_ISSUES_PER_DETECTOR]
#      46     maybe_print(f" {len(detected_issues)} issues detected.", verbose=verbose)
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/giskard/scanner/performance/model_bias_detector.py:52, in ModelBiasDetector.run(self, model, dataset)
#      49 slices = [s for s in slices if 0.05 * len(dataset) <= len(dataset.slice(s))]
#      51 # Create issues from the slices
# ---> 52 issues = self._find_issues(slices, model, dataset)
#      54 return issues
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/giskard/scanner/performance/model_bias_detector.py:111, in ModelBiasDetector._find_issues(self, slices, model, dataset)
#     109 precooked = PrecookedModel.from_model(model, dataset)
#     110 detector = IssueFinder(self.metrics, self.threshold)
# --> 111 issues = detector.detect(precooked, dataset, slices)
#     113 return issues
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/giskard/scanner/performance/model_bias_detector.py:131, in IssueFinder.detect(self, model, dataset, slices)
#     128 issues = []
#     130 for metric in metrics:
# --> 131     issues.extend(self._detect_for_metric(model, dataset, slices, metric))
#     133 # Group issues by slice and keep only the most critical
#     134 issues_by_slice = defaultdict(list)
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/giskard/scanner/performance/model_bias_detector.py:152, in IssueFinder._detect_for_metric(self, model, dataset, slices, metric)
#     148 def _detect_for_metric(
#     149     self, model: BaseModel, dataset: Dataset, slices: Sequence[SlicingFunction], metric: PerformanceMetric
#     150 ):
#     151     # Calculate the metric on the reference dataset
# --> 152     ref_metric_val = metric(model, dataset)
#     154     # Now we calculate the metric on each slice and compare it to the reference
#     155     issues = []
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/giskard/scanner/performance/metrics.py:25, in ClassificationPerformanceMetric.__call__(self, model, dataset)
#      22 y_true = dataset.df[dataset.target]
#      23 y_pred = model.predict(dataset).prediction
# ---> 25 return self._calculate_metric(y_true, y_pred, model)
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/giskard/scanner/performance/metrics.py:37, in Accuracy._calculate_metric(self, y_true, y_pred, model)
#      36 def _calculate_metric(self, y_true, y_pred, model: BaseModel):
# ---> 37     return sklearn.metrics.accuracy_score(y_true, y_pred)
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
#     197     # message to avoid confusion.
#     198     msg = re.sub(
#     199         r"parameter of \w+ must be",
#     200         f"parameter of {func.__qualname__} must be",
#     201         str(e),
#     202     )
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:221, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     155 """Accuracy classification score.
#     156
#     157 In multilabel classification, this function computes subset accuracy:
#    (...)
#     217 0.5
#     218 """
#     220 # Compute accuracy for each possible representation
# --> 221 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     222 check_consistent_length(y_true, y_pred, sample_weight)
#     223 if y_type.startswith("multilabel"):
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:86, in _check_targets(y_true, y_pred)
#      59 def _check_targets(y_true, y_pred):
#      60     """Check that y_true and y_pred belong to the same classification task.
#      61
#      62     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      84     y_pred : array or indicator matrix
#      85     """
# ---> 86     check_consistent_length(y_true, y_pred)
#      87     type_true = type_of_target(y_true, input_name="y_true")
#      88     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/IdeaProjects/GiskardExamples/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:397, in check_consistent_length(*arrays)
#     395 uniques = np.unique(lengths)
#     396 if len(uniques) > 1:
# --> 397     raise ValueError(
#     398         "Found input variables with inconsistent numbers of samples: %r"
#     399         % [int(l) for l in lengths]
#     400     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1000, 1278]
