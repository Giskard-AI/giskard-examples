# %% [markdown]
# # About Giskard
#
# Open-Source CI/CD platform for ML teams. Deliver ML products, better & faster.
#
# *   Collaborate faster with feedback from business stakeholders.
# *   Deploy automated tests to eliminate regressions, errors & biases.
#
# 🏡 [Website](https://giskard.ai/)
#
# 📗 [Documentation](https://docs.giskard.ai/)

# %% [markdown]
# # Install the giskard preview package

# %%
# !pip install ./preview-dist/giskard-1.8.0-py3-none-any.whl
# !python pip install great_expectations
# Out:
# Processing ./preview-dist/giskard-1.8.0-py3-none-any.whl
# Collecting mlflow@ git+https://github.com/Giskard-AI/mlflow.git
#   Cloning https://github.com/Giskard-AI/mlflow.git to /private/var/folders/nf/w2h_y58n4sxdyjmq4qlwcxym0000gn/T/pip-install-yypu3ryu/mlflow_be501ba7e34942f5984e1cd82bd29da2
#   Running command git clone --filter=blob:none --quiet https://github.com/Giskard-AI/mlflow.git /private/var/folders/nf/w2h_y58n4sxdyjmq4qlwcxym0000gn/T/pip-install-yypu3ryu/mlflow_be501ba7e34942f5984e1cd82bd29da2
#   Resolved https://github.com/Giskard-AI/mlflow.git to commit 7580281a40c27aeb8f962f392e171619d6574c37
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: lockfile<0.13.0,>=0.12.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (0.12.2)
# Requirement already satisfied: mixpanel<5.0.0,>=4.10.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (4.10.0)
# Requirement already satisfied: ipython<8.0.0,>=7.0.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (7.34.0)
# Requirement already satisfied: numpy<1.22.0,>=1.21.6 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (1.21.6)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (1.10.5)
# Requirement already satisfied: setuptools<68.0.0,>=65.4.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (67.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (2.28.2)
# Requirement already satisfied: importlib_metadata<5.0.0,>=4.11.4 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (4.13.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.11.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (4.11.2)
# Requirement already satisfied: shap<0.42.0,>=0.41.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (0.41.0)
# Requirement already satisfied: eli5<0.14.0,>=0.13.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (0.13.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.46.3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (1.51.3)
# Requirement already satisfied: zstandard<0.16.0,>=0.15.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (0.15.2)
# Requirement already satisfied: scikit-learn<1.1.0,>=1.0.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (1.0.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (8.2.2)
# Requirement already satisfied: cloudpickle<3.0.0,>=2.1.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (2.2.1)
# Requirement already satisfied: pycryptodome<4.0,>=3.17 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (3.17)
# Requirement already satisfied: protobuf<4.0.0,>=3.9.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (3.19.6)
# Requirement already satisfied: python-daemon<3.0.0,>=2.3.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (2.3.2)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (8.1.3)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.46.3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (1.48.2)
# Requirement already satisfied: scipy<1.8,>=1.7.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (1.7.3)
# Requirement already satisfied: requests-toolbelt<0.10.0,>=0.9.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (0.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (4.64.1)
# Requirement already satisfied: psutil<6.0.0,>=5.9.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (5.9.4)
# Requirement already satisfied: pandas<2.0.0,>=1.3.5 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from giskard==1.8.0) (1.3.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.11.1->giskard==1.8.0) (2.4)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from eli5<0.14.0,>=0.13.0->giskard==1.8.0) (0.9.0)
# Requirement already satisfied: six in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from eli5<0.14.0,>=0.13.0->giskard==1.8.0) (1.16.0)
# Requirement already satisfied: attrs>17.1.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from eli5<0.14.0,>=0.13.0->giskard==1.8.0) (22.2.0)
# Requirement already satisfied: graphviz in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from eli5<0.14.0,>=0.13.0->giskard==1.8.0) (0.20.1)
# Requirement already satisfied: jinja2>=3.0.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from eli5<0.14.0,>=0.13.0->giskard==1.8.0) (3.1.2)
# Requirement already satisfied: googleapis-common-protos>=1.5.5 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from grpcio-status<2.0.0,>=1.46.3->giskard==1.8.0) (1.58.0)
# Requirement already satisfied: zipp>=0.5 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from importlib_metadata<5.0.0,>=4.11.4->giskard==1.8.0) (3.15.0)
# Requirement already satisfied: appnope in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (0.1.3)
# Requirement already satisfied: matplotlib-inline in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (0.1.6)
# Requirement already satisfied: decorator in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (4.8.0)
# Requirement already satisfied: backcall in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (0.2.0)
# Requirement already satisfied: pygments in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (2.14.0)
# Requirement already satisfied: pickleshare in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from ipython<8.0.0,>=7.0.0->giskard==1.8.0) (5.9.0)
# Requirement already satisfied: urllib3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mixpanel<5.0.0,>=4.10.0->giskard==1.8.0) (1.26.14)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.5->giskard==1.8.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.5->giskard==1.8.0) (2022.7.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from pydantic<2.0.0,>=1.10.2->giskard==1.8.0) (4.5.0)
# Requirement already satisfied: docutils in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from python-daemon<3.0.0,>=2.3.1->giskard==1.8.0) (0.19)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->giskard==1.8.0) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->giskard==1.8.0) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->giskard==1.8.0) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from scikit-learn<1.1.0,>=1.0.0->giskard==1.8.0) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from scikit-learn<1.1.0,>=1.0.0->giskard==1.8.0) (1.2.0)
# Requirement already satisfied: slicer==0.0.7 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from shap<0.42.0,>=0.41.0->giskard==1.8.0) (0.0.7)
# Requirement already satisfied: numba in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from shap<0.42.0,>=0.41.0->giskard==1.8.0) (0.56.4)
# Requirement already satisfied: packaging>20.9 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from shap<0.42.0,>=0.41.0->giskard==1.8.0) (22.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (6.0)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (0.17.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (0.4.3)
# Requirement already satisfied: gunicorn<21 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (20.1.0)
# Requirement already satisfied: pyarrow<11,>=4.0.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (10.0.1)
# Requirement already satisfied: docker<7,>=4.0.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (6.0.1)
# Requirement already satisfied: entrypoints<1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (0.4)
# Requirement already satisfied: Flask<3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (2.2.3)
# Requirement already satisfied: markdown<4,>=3.3 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (3.4.1)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (3.1.31)
# Requirement already satisfied: querystring-parser<2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (1.2.4)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (1.4.46)
# Requirement already satisfied: matplotlib<4 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (3.5.3)
# Requirement already satisfied: alembic<2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (1.9.4)
# Requirement already satisfied: Mako in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from alembic<2->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (1.2.4)
# Requirement already satisfied: oauthlib>=3.1.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (3.2.2)
# Requirement already satisfied: pyjwt>=1.7.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (2.6.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from docker<7,>=4.0.0->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (1.5.1)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from Flask<3->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from Flask<3->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (2.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from gitpython<4,>=2.1.0->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (4.0.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0.0,>=7.0.0->giskard==1.8.0) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from jinja2>=3.0.0->eli5<0.14.0,>=0.13.0->giskard==1.8.0) (2.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (9.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0.0,>=7.0.0->giskard==1.8.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0,>=7.0.0->giskard==1.8.0) (0.2.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from numba->shap<0.42.0,>=0.41.0->giskard==1.8.0) (0.39.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow@ git+https://github.com/Giskard-AI/mlflow.git->giskard==1.8.0) (5.0.0)
# Installing collected packages: giskard
#   Attempting uninstall: giskard
#     Found existing installation: giskard 1.8.0
#     Uninstalling giskard-1.8.0:
#       Successfully uninstalled giskard-1.8.0
# Successfully installed giskard-1.8.0
# python: can't open file '/Users/kevinmessiaen/work/giskard-examples/pip': [Errno 2] No such file or directory

# %% [markdown]
# ## Installing other packages

# %%
# !pip install transformers torch nltk
# Out:
# Requirement already satisfied: transformers in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (4.26.1)
# Requirement already satisfied: torch in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (1.13.1)
# Requirement already satisfied: nltk in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (3.8.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from transformers) (22.0)
# Requirement already satisfied: typing-extensions in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from torch) (4.5.0)
# Requirement already satisfied: click in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages (from requests->transformers) (2022.12.7)

# %%
import giskard
giskard.__version__
# Out:
# UDF repository is not available because the 'GIT_REPOSITORY' environment variable is not set
# '1.8.0'

# %% [markdown]
# ## Connect the external worker in daemon mode

# %%
# !giskard worker start -u http://localhost:19000 -k 'YOUR_API_KEY_HERE' -d
# Out:
# UDF repository is not available because the 'GIT_REPOSITORY' environment variable is not set

# %% [markdown]
# # Start by creating a ML model 🚀🚀🚀

# %% [markdown]
# Download the categorized email files from Berkeley.

# %%
# !wget http://bailando.sims.berkeley.edu/enron/enron_with_categories.tar.gz
# !tar zxf enron_with_categories.tar.gz
# !rm enron_with_categories.tar.gz
# Out:
# --2023-03-02 12:18:29--  http://bailando.sims.berkeley.edu/enron/enron_with_categories.tar.gz
# Resolving bailando.sims.berkeley.edu (bailando.sims.berkeley.edu)... 128.32.78.19
# Connecting to bailando.sims.berkeley.edu (bailando.sims.berkeley.edu)|128.32.78.19|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://bailando.berkeley.edu/enron/enron_with_categories.tar.gz [following]
# --2023-03-02 12:18:32--  https://bailando.berkeley.edu/enron/enron_with_categories.tar.gz
# Resolving bailando.berkeley.edu (bailando.berkeley.edu)... 128.32.78.19
# Connecting to bailando.berkeley.edu (bailando.berkeley.edu)|128.32.78.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4523350 (4.3M) [application/x-gzip]
# Saving to: ‘enron_with_categories.tar.gz’
#
# enron_with_categori 100%[===================>]   4.31M   829KB/s    in 5.7s
#
# 2023-03-02 12:18:39 (778 KB/s) - ‘enron_with_categories.tar.gz’ saved [4523350/4523350]

# %%
import email
import glob

from collections import defaultdict

import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from string import punctuation

import pandas as pd
from dateutil import parser
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer


from sklearn.linear_model import LogisticRegression
from sklearn import model_selection

# %% [markdown]
# Various imports and the list of categories from http://bailando.sims.berkeley.edu/enron/enron_categories.txt.

# %%
nltk.download('punkt')
nltk.download('stopwords')

stoplist = set(stopwords.words('english') + list(punctuation))
stemmer = PorterStemmer()


# http://bailando.sims.berkeley.edu/enron/enron_categories.txt
idx_to_cat = {
    1: 'REGULATION',
    2: 'INTERNAL',
    3: 'INFLUENCE',
    4: 'INFLUENCE',
    5: 'INFLUENCE',
    6: 'CALIFORNIA CRISIS',
    7: 'INTERNAL',
    8: 'INTERNAL',
    9: 'INFLUENCE',
    10: 'REGULATION',
    11: 'talking points',
    12: 'meeting minutes',
    13: 'trip reports'}

idx_to_cat2 = {
    1: 'regulations and regulators (includes price caps)',
    2: 'internal projects -- progress and strategy',
    3: ' company image -- current',
    4: 'company image -- changing / influencing',
    5: 'political influence / contributions / contacts',
    6: 'california energy crisis / california politics',
    7: 'internal company policy',
    8: 'internal company operations',
    9: 'alliances / partnerships',
    10: 'legal advice',
    11: 'talking points',
    12: 'meeting minutes',
    13: 'trip reports'}


LABEL_CAT = 3  # we'll be using the 2nd-level category "Primary topics" because the two first levels provide categories that are not mutually exclusive. see : https://bailando.berkeley.edu/enron/enron_categories.txt

# get_labels returns a dictionary representation of these labels.
def get_labels(filename):
    with open(filename + '.cats') as f:
        labels = defaultdict(dict)
        line = f.readline()
        while line:
            line = line.split(',')
            top_cat, sub_cat, freq = int(line[0]), int(line[1]), int(line[2])
            labels[top_cat][sub_cat] = freq
            line = f.readline()
    return dict(labels)


email_files = [f.replace('.cats', '') for f in glob.glob('enron_with_categories/*/*.cats')]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kevinmessiaen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kevinmessiaen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Build dataframe

# %%
columns_name = ['Target', 'Subject', 'Content', 'Week_day', 'Year', 'Month', 'Hour', 'Nb_of_forwarded_msg']


data = pd.DataFrame(columns=columns_name)

for email_file in email_files:
    values_to_add = {}

    # Target is the sub-category with maximum frequency
    if LABEL_CAT in get_labels(email_file):
      sub_cat_dict = get_labels(email_file)[LABEL_CAT]
      target_int = max(sub_cat_dict, key=sub_cat_dict.get)
      values_to_add['Target'] = str(idx_to_cat[target_int])

    # Features are metadata from the email object
    filename = email_file+'.txt'
    with open(filename) as f:

      message = email.message_from_string(f.read())
  
      values_to_add['Subject'] = str(message['Subject'])
      values_to_add['Content'] = str(message.get_payload())
     
      date_time_obj = parser.parse(message['Date'])
      values_to_add['Week_day'] = date_time_obj.strftime("%A")
      values_to_add['Year'] = date_time_obj.strftime("%Y")
      values_to_add['Month'] = date_time_obj.strftime("%B")
      values_to_add['Hour'] = int(date_time_obj.strftime("%H"))

      # Count number of forwarded mails
      number_of_messages = 0
      for line in message.get_payload().split('\n'):
        if ('forwarded' in line.lower() or 'original' in line.lower()) and '--' in line:
            number_of_messages += 1
      values_to_add['Nb_of_forwarded_msg'] = number_of_messages
    
    row_to_add = pd.Series(values_to_add)
    data = data.append(row_to_add, ignore_index=True)

# %% [markdown]
# ## Filter Dataframe

# %%
# We filter 879 rows (if Primary topics exists (i.e. if coarse genre 1.1 is selected) )
data_filtered = data[data["Target"].notnull()]

#Exclude target category with very few rows ; 812 rows remains
excluded_category = [idx_to_cat[i] for i in [11,12,13]]
data_filtered = data_filtered[data_filtered["Target"].isin(excluded_category) == False]
num_classes = len(data_filtered["Target"].value_counts())

# %%
column_types={       
        'Target': "category",
        "Subject": "text",
        "Content": "text",
        "Week_day": "category",
        "Month": "category",
        "Hour": "numeric",
        "Nb_of_forwarded_msg": "numeric",
        "Year": "numeric"
    }

# %% [markdown]
# ## Training with scikit learn pipeline

# %%
feature_types = {i:column_types[i] for i in column_types if i!='Target'}

columns_to_scale = [key for key in feature_types.keys() if feature_types[key]=="numeric"]

numeric_transformer = Pipeline([('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])


columns_to_encode = [key for key in feature_types.keys() if feature_types[key]=="category"]

categorical_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
        ('onehot', OneHotEncoder(handle_unknown='ignore',sparse=False)) ])
text_transformer = Pipeline([
                      ('vect', CountVectorizer(stop_words=stoplist)),
                      ('tfidf', TfidfTransformer())
                     ])
preprocessor = ColumnTransformer(
    transformers=[
      ('num', numeric_transformer, columns_to_scale),
      ('cat', categorical_transformer, columns_to_encode),
      ('text_Mail', text_transformer, "Content")
    ]
)

clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression(max_iter =1000))])

# %% [markdown]
# ## Split train/test

# %%
feature_types = {i:column_types[i] for i in column_types if i!="Target"}
Y = data_filtered["Target"]
X = data_filtered.drop(columns=["Target"])
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(X, Y,test_size=0.20, random_state = 30, stratify = Y)

# %% [markdown]
# # Learning phase

# %%
clf.fit(X_train, Y_train)
print("model score: %.3f" % clf.score(X_test, Y_test))
# Out:
# model score: 0.500

# %%
train_data = pd.concat([X_train, Y_train], axis=1)
test_data = pd.concat([X_test, Y_test ], axis=1)

# %% [markdown]
# # Upload the model in Giskard 🚀🚀🚀

# %% [markdown]
# ## Initiate a project

# %%
from giskard import GiskardClient
from giskard.ml_worker.core.suite import Suite

url = "http://localhost:19000" # If Giskard is installed locally (for installation, see: https://docs.giskard.ai/start/guides/installation)
#url = "http://app.giskard.ai" # If you want to upload on giskard URL
token = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhZG1pbiIsImF1dGgiOiJST0xFX0FETUlOIiwiaWQiOjYsInRva2VuX3R5cGUiOiJVSSIsImV4cCI6MTY3NTkzNTkxNn0.B9P02Zi8lq5OWzBX6MFH9gbJ1zaVal4F7Eh_cErSH2w" # you can generate your API token in the Admin tab of the Giskard application (for installation, see: https://docs.giskard.ai/start/guides/installation)

client = GiskardClient(url, token)

# your_project = client.create_project("project_key", "PROJECT_NAME", "DESCRIPTION")
# Choose the arguments you want. But "project_key" should be unique and in lower case
enron = client.create_project("enron_test", "Email Classification", "Email Classification")

# If you've already created a project with the key "enron_demo" use
#enron = client.get_project("enron")

# %% [markdown]
# ### New way to upload your model and dataset

# %% [markdown]
# #### preprocessor and classifier as a pipeline clf

# %%
from giskard import Model, SKLearnModel, GiskardClient, Dataset

# Wrap your clf with SKLearnModel from Giskard
my_model = SKLearnModel(clf=clf, model_type="classification")

# Wrap your dataset with Dataset from Giskard
my_test_dataset = Dataset(test_data, name="test dataset", target="Target", feature_types=column_types)

# save model and dataset to Giskard server
mid = my_model.upload(client, "enron_test", validate_ds=my_test_dataset)
did = my_test_dataset.save(client, "enron_test")
# Out:
# /Users/kevinmessiaen/work/giskard/python-client/.venv/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Model successfully uploaded to project key 'enron_test' with ID = 7bce419e-88e9-4bfa-bc91-ee506a736066
# Dataset successfully uploaded to project key 'enron_test' with ID = eec31fa1-97bd-41bf-9927-6dbf7fdf38b7

# %% [markdown]
# # Create a uniqueness and data quality test classes

# %%
from giskard.ml_worker.core.test_result import TestResult
from giskard.ml_worker.testing.registry.giskard_test import GiskardTest
import great_expectations as ge

class UniquenessTest(GiskardTest):

    def __init__(self):
        super().__init__()

    def set_params(self, dataset: Dataset = None, column_name: str = None):
        self.dataset = dataset
        self.column_name = column_name

        return self

    def execute(self) -> TestResult:
        dataframe = ge.from_pandas(self.dataset.df)
        uniqueness = dataframe.expect_column_values_to_be_unique(column=self.column_name)
        passed = uniqueness["success"]
        metric = uniqueness["result"]["element_count"]
        return TestResult(passed=passed, metric=metric)

class DataQuality(GiskardTest):

    def __init__(self):
        super().__init__()

    def set_params(self,
                   dataset: Dataset = None,
                   threshold: float = 0.5,
                   column_name: str = None,
                   category: str = None):
        self.dataset = dataset
        self.threshold = threshold
        self.column_name = column_name
        self.category = category

        return self

    def execute(self) -> TestResult:
        freq_of_cat = self.dataset.df[self.column_name].value_counts()[self.category]/ (len(self.dataset.df))
        passed = freq_of_cat < self.threshold

        return TestResult(passed=passed, metric=freq_of_cat)

# %% [markdown]
# # Run a suite with those two tests

# %%
passed, results = Suite().add_test(UniquenessTest().set_params(column_name='Subject'), "uniq").add_test(DataQuality().set_params(column_name='Month', category='August'), "quality").run(dataset=my_test_dataset)

print(f"Result: {passed}")
print(f"UniquenessTest: {results['uniq'].passed} {results['uniq'].metric}")
print(f"DataQuality: {results['uniq'].passed} {results['uniq'].metric}")
# Out:
# Result: False
# UniquenessTest: False 170
# DataQuality: False 170

# %% [markdown]
# # Now lets upload the test suite

# %%
Suite().add_test(UniquenessTest().set_params(column_name='Subject'), "uniq").add_test(DataQuality().set_params(column_name='Month', category='August'), "quality").save(client, 'enron_test')

# %% [markdown]
# Now we can go on the project tab "Test suite new" to see and execute the test suite. Furthermore, the two test will be available inside the Giskard catalog
